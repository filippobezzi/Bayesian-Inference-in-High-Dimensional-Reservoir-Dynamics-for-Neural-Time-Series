# %%
import matplotlib.pyplot as plt
import numpy as np
import pyro
import scipy.io as sio
import torch
import torch.nn as nn
from pyro.infer.autoguide import AutoLowRankMultivariateNormal
from pyro.optim import Adam
from sklearn.decomposition import PCA

from src.dataset import DataGenerator, ESNDataset, partition_dataset
from src.function_calibration import calibrate, check_calibration
from src.functions_metrics import (
    combine_metrics_dictionaries,
    evaluate_metrics,
    evaluate_metrics_multiple,
    evaluate_metrics_qr,
    print_metrics,
)
from src.methods import ESNMCMC, ESNQR, CheckLoss, ESNVariational
from src.models import MLP, SSVS, BayesianModel, BayesianNeuralNetwork
from src.radial_plot import radial_plot
from src.reservoir import Reservoir
from src.visualization import (
    plot_calibrated_test,
    plot_functional_connectivity,
    plot_probabilistic_forecast,
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Synthetic

# %%
time_steps = 25000
burnin_steps = 1000
stride = 10
tau = 17
n = 10
beta = 0.2
gamma = 0.1
delta_t = 0.1

X, _ = DataGenerator(time_steps, tau, n, beta, gamma, delta_t).generate_data()
X = X[burnin_steps::stride]
X += torch.randn(X.shape) * 0.3
X = X.float()

# %%
plt.plot(X)
plt.xlim(200, 400)
plt.show()

# %% [markdown]
# ## Create the Reservoir

# %%
num_neurons_synth = 500
num_features_synth = X.shape[1]
reservoir_synth = Reservoir(
    input_features=num_features_synth, num_neurons=num_neurons_synth
)

# %% [markdown]
# ## Generate the $(s,x)$ dataset

# %%
burnin_steps = 50
states_synth = torch.zeros((X.shape[0] - 1, num_neurons_synth))

for i, x in enumerate(X[:-1]):
    states_synth[i, :] = reservoir_synth(x)

reservoir_synth.reset_state()
dataset_synth = ESNDataset(states_synth[burnin_steps:-1], X[burnin_steps + 1 :])

# %%
train_set, cal_set, test_set = partition_dataset([dataset_synth], num_partitions=10)

# %%
# move datasets to gpu
train_set = train_set.to(device)
cal_set = cal_set.to(device)
test_set = test_set.to(device)

# %% [markdown]
# ## MCMC

# %% [markdown]
# We rely on Hamiltonian Monte Carlo methods in order to estimate the posterior distribution of $R$ (and $b$).
# In particular we use the NUTS (No U-Turn Sampler) method, which is a variant of the standard HMC, that generally results in faster exploration of the parameter space.
#
# Operatively we generate one or more Markov Chains, discarding the first `warmup_steps` samples from them.
# The remaining samples of the parameters will be used to perform predictions on the test set, allowing us to give an estimation of the results.

# %%
mcmc_model_synth = BayesianModel(
    in_features=num_neurons_synth, out_features=num_features_synth
).to(device)

# %%
esn_mcmc = ESNMCMC(mcmc_model_synth)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/250 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_mcmc_synth = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set
)
# Out:
# Empirical Coverage: 0.944 ± 0.001
# Calibration Error:  0.00076 ± 0.00006
# mCRPS (Normalized): 0.0964 ± 0.0015
# Width: 3.436 ± 0.045

# %% [markdown]
# ### calibration algorithm

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.0812%
# Mean MSCE (Calibrated Test): 0.1494%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[25], line 1
#
# ----> 1 plot_calibrated_test(
#
#       2     Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
#
#       3 )
#
#
#
# File ~/Bayesian-Inference-in-High-Dimensional-Reservoir-Dynamics-for-Neural-Time-Series/src/visualization.py:320, in plot_calibrated_test(Y_test_array, y_pred, adj_quantiles)
#
#     317 Y_test_reg = Y_test_array[:, region_idx]
#
#     319 # Extract calibrated bounds utilizing the adjusted quantiles
#
# --> 320 median_prediction_cal = torch.quantile(y_pred_test_reg, 0.5, dim=0).numpy()
#
#     321 lower_bound_cal = torch.quantile(y_pred_test_reg, q_lower_adj, dim=0).numpy()
#
#     322 upper_bound_cal = torch.quantile(y_pred_test_reg, q_upper_adj, dim=0).numpy()
#
#
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ## MCMC with PCA

# %% [markdown]
# Here we perform the same process as above, but with a Principal Component Analysis reduction applied to the reservoir state.

# %%
n_components = 16
pca = PCA(n_components)

# %%
# move datasets to cpu
train_set = train_set.to(torch.device("cpu"))
cal_set = cal_set.to(torch.device("cpu"))
test_set = test_set.to(torch.device("cpu"))

# %%
# fit pca
pca = pca.fit(train_set.states.numpy())

# %%
# apply pca to the sets
train_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(train_set.states.numpy())),
    x=train_set.x,
    mu=train_set.mu,
    std=train_set.mu,
    device=device,
)
cal_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(cal_set.states.numpy())),
    x=cal_set.x,
    mu=cal_set.mu,
    std=cal_set.mu,
    device=device,
)
test_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(test_set.states.numpy())),
    x=test_set.x,
    mu=test_set.mu,
    std=test_set.mu,
    device=device,
)

# %%
mcmc_pca_model_synth = BayesianModel(
    in_features=n_components, out_features=num_features_synth
).to(device)

# %%
esn_mcmc = ESNMCMC(mcmc_pca_model_synth)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_pca_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/250 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_pca_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_mcmc_pca_synth = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set
)
# Out:
# Empirical Coverage: 0.944 ± 0.001
# Calibration Error:  0.00076 ± 0.00006
# mCRPS (Normalized): 0.0964 ± 0.0015
# Width: 3.436 ± 0.045

# %% [markdown]
# ### calibration algorithm

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.0812%
# Mean MSCE (Calibrated Test): 0.1494%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[25], line 1
#
# ----> 1 plot_calibrated_test(
#
#       2     Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
#
#       3 )
#
#
#
# File ~/Bayesian-Inference-in-High-Dimensional-Reservoir-Dynamics-for-Neural-Time-Series/src/visualization.py:320, in plot_calibrated_test(Y_test_array, y_pred, adj_quantiles)
#
#     317 Y_test_reg = Y_test_array[:, region_idx]
#
#     319 # Extract calibrated bounds utilizing the adjusted quantiles
#
# --> 320 median_prediction_cal = torch.quantile(y_pred_test_reg, 0.5, dim=0).numpy()
#
#     321 lower_bound_cal = torch.quantile(y_pred_test_reg, q_lower_adj, dim=0).numpy()
#
#     322 upper_bound_cal = torch.quantile(y_pred_test_reg, q_upper_adj, dim=0).numpy()
#
#
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ## Bayesian Neural Network

# %% [markdown]
# A Bayesian Neural Network is a Neural Networks whose parameters are not set in stone (in evaluation time, at least), but instead they are sampled.

# %%
# move datasets to gpu
train_set = train_set.to(device)
cal_set = cal_set.to(device)
test_set = test_set.to(device)

# %%
layer_sizes = [
    num_neurons_synth,
    128,
    16,
    num_features_synth,
]
activation = nn.ReLU()
nn_model_synth = BayesianNeuralNetwork(
    layer_sizes, activation, sigma_bias=1.0, sigma_weight=16.0
).to(device)

# %%
esn_mcmc = ESNMCMC(nn_model_synth)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 20
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/170 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_bnn_synth = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set, n_trials=1
)
# Out:
# Empirical Coverage: 0.876 ± 0.003
# Calibration Error:  0.00242 ± 0.00017
# mCRPS (Normalized): 0.1005 ± 0.0010
# Width: 3.685 ± 0.033

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.3052%
# Mean MSCE (Calibrated Test): 0.2551%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## SVI

# %%
svi_model_synth = BayesianModel(
    in_features=num_neurons_synth, out_features=num_features_synth, scale=1.0
).to(device)

# %%
# Setup Optimizer
LR = 0.0001
EPOCHS = 100

optimizer = Adam({"lr": LR})

# %%
# PYRO GUIDE

RANK = int(np.sqrt(num_neurons_synth))  # Rank for the Multivariate Normal
guide = AutoLowRankMultivariateNormal(svi_model_synth, rank=RANK)

# %%
esn_var_synth = ESNVariational(
    svi_model_synth,
    guide,
    optimizer,
)

# %%
loss_history = esn_var_synth.train(train_set, EPOCHS, batch_size=64, shuffle=True)
plt.plot(loss_history)
plt.show()
# Out:
# Training Pyro ESN:   0%|          | 1/400 [00:01<07:52,  1.18s/it, Loss=22194.7982]
# Epoch 0 | Total ELBO Loss: 22194.7982
# Training Pyro ESN:  25%|██▌       | 101/400 [00:27<01:17,  3.84it/s, Loss=8848.8895]
# Epoch 100 | Total ELBO Loss: 8848.8895
# Training Pyro ESN:  50%|█████     | 201/400 [00:53<00:51,  3.84it/s, Loss=5206.4527]
# Epoch 200 | Total ELBO Loss: 5206.4527
# Training Pyro ESN:  75%|███████▌  | 301/400 [01:20<00:27,  3.61it/s, Loss=3147.2196]
# Epoch 300 | Total ELBO Loss: 3147.2196
# Training Pyro ESN: 100%|██████████| 400/400 [01:48<00:00,  3.70it/s, Loss=1960.0415]

# %%
y_pred = esn_var_synth.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_svi_synth = evaluate_metrics_multiple(
    esn_obj=esn_var_synth, y_true=test_set.x.cpu(), test_set=test_set, n_trials=1
)
# Out:
# Empirical Coverage: 0.619 ± 0.006
# Calibration Error:  0.01723 ± 0.00046
# mCRPS (Normalized): 0.0937 ± 0.0009
# Width: 1.421 ± 0.014

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_var_synth.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 1.0509%
# Mean MSCE (Calibrated Test): 0.3355%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## Stochastic search variable selection (SSVS)

# %% [markdown]
# Reservoir computing generates a high-dimensional state space containing hundreds of random features. Many of these features are irrelevant and can simply be interpreted as noise. Trying to learn all of them can slow down Bayesian inference algorithms like MCMC, a phenomenon related to the curse of dimensionality.
#
# In order to try to work around this problem, we can implement the **Bayesian Stochastic Search Variable Selection (SSVS)** algorithm. The core idea is to introduce *sparsity* in the Reservoir parameter space by placing a "shrinking" prior (in our case, the **Horseshoe** prior) on the readout weights.
# This specific choice of prior actively shrinks the weights of useless nodes toward zero, focusing the MCMC sampling only on the most promising areas of the parameter space.
#
# In order to induce sparsity, the Horseshoe prior is implemented using a Half-Cauchy distribution $\mathcal{C}^{+}$:
#
# * **Global Shrinkage:** $\tau \sim \mathcal{C}^{+}(0, 1)$
# * **Local Shrinkage:** $\lambda_i \sim \mathcal{C}^{+}(0, 1)$
# * **Reservoir Weights:** $\beta_i \sim \mathcal{N}(0, \lambda_i^2 \tau^2)$
# * **Likelihood:** $y \sim \mathcal{N}(X\beta + b, \sigma^2)$
#
# <p align="center">
#   <img src="ssvs_horseshoe_prior_small.png" width="600">
# </p>
#
# Here, the Half-Cauchy distribution is specifically chosen for its sharp peak at zero and its heavy tails. The global parameter $\tau$ acts as a master threshold, aggressively shrinking all weights toward zero to suppress noise. Conversely, the local parameter $\lambda_i$ acts as an amplifier, allowing individual, highly relevant features to escape this global shrinkage and maintain large values.
#
# While SSVS successfully solves the statistical curse of dimensionality by filtering out the noise and providing highly interpretable models, it introduces a new challenge. The hierarchical combination of $\tau$ and $\lambda_i$ creates a highly complex posterior geometry, known in literature as Neal's Funnel.
# This causes the MCMC to be computationally slower than standard Bayesian Regression: gradient-based algorithms like NUTS are forced to take extremely small step sizes to correctly navigate this narrow probabilistic space without diverging, resulting in significantly longer training times.

# %%
ssvs_model_synth = SSVS(num_neurons_synth, num_features_synth).to(device)

# %%
esn_mcmc = ESNMCMC(ssvs_model_synth)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup:  14%|█▍        | 36/250 [01:01,  4.28s/it, step size=7.40e-04, acc. prob=0.773]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[11], line 7
#
#       4 num_chains = 1
#
#       5 mp_context = "spawn"
#
# ----> 7 esn_mcmc.run(
#
#       8     train_set,
#
#       9     warmup_steps=warmup_steps,
#
#      10     num_samples=num_samples,
#
#      11     num_chains=num_chains,
#
#      12     mp_context=mp_context,
#
#      13 )
#
#
#
# File ~/Bayesian-Inference-in-High-Dimensional-Reservoir-Dynamics-for-Neural-Time-Series/src/methods.py:38, in ESNMCMC.run(self, dataset, **kwargs)
#
#      36 nuts_kernel = NUTS(self.model)
#
#      37 mcmc = MCMC(nuts_kernel, **kwargs)
#
# ---> 38 mcmc.run(dataset.states, dataset.x)
#
#      39 self.posterior_samples = mcmc.get_samples()
#
#      40 return
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#
#      25 def _context_wrap(
#
#      26     context: "Messenger",
#
#      27     fn: Callable,
#
#      28     *args: Any,
#
#      29     **kwargs: Any,
#
#      30 ) -> Any:
#
#      31     with context:
#
# ---> 32         return fn(*args, **kwargs)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/api.py:565, in MCMC.run(self, *args, **kwargs)
#
#     556 with optional(
#
#     557     pyro.validation_enabled(not self.disable_validation),
#
#     558     self.disable_validation is not None,
#
#    (...)    562     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#
#     563     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#
#     564     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
#
# --> 565     for x, chain_id in self.sampler.run(*args, **kwargs):
#
#     566         if num_samples[chain_id] == 0:
#
#     567             num_samples[chain_id] += 1
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/api.py:225, in _UnarySampler.run(self, *args, **kwargs)
#
#     223 logger = initialize_logger(logger, "", progress_bar)
#
#     224 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
#
# --> 225 for sample in _gen_samples(
#
#     226     self.kernel,
#
#     227     self.warmup_steps,
#
#     228     self.num_samples,
#
#     229     hook_w_logging,
#
#     230     i if self.num_chains > 1 else None,
#
#     231     *args,
#
#     232     **kwargs
#
#     233 ):
#
#     234     yield sample, i  # sample, chain_id
#
#     235 self.kernel.cleanup()
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/api.py:152, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#
#     150 yield {name: params[name].shape for name in save_params}
#
#     151 for i in range(warmup_steps):
#
# --> 152     params = kernel.sample(params)
#
#     153     hook(
#
#     154         kernel,
#
#     155         params,
#
#     156         "Warmup [{}]".format(chain_id) if chain_id is not None else "Warmup",
#
#     157         i,
#
#     158     )
#
#     159 for i in range(num_samples):
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:452, in NUTS.sample(self, params)
#
#     450     z_right_grads = new_tree.z_right_grads
#
#     451 else:  # go the the left, start from the left leaf of current tree
#
# --> 452     new_tree = self._build_tree(
#
#     453         z_left,
#
#     454         r_left,
#
#     455         z_left_grads,
#
#     456         log_slice,
#
#     457         direction,
#
#     458         tree_depth,
#
#     459         energy_current,
#
#     460     )
#
#     461     z_left = new_tree.z_left
#
#     462     r_left = new_tree.r_left
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#
#     254     return self._build_basetree(
#
#     255         z, r, z_grads, log_slice, direction, energy_current
#
#     256     )
#
#     258 # build the first half of tree
#
# --> 259 half_tree = self._build_tree(
#
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#
#     261 )
#
#     262 z_proposal = half_tree.z_proposal
#
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#
#     254     return self._build_basetree(
#
#     255         z, r, z_grads, log_slice, direction, energy_current
#
#     256     )
#
#     258 # build the first half of tree
#
# --> 259 half_tree = self._build_tree(
#
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#
#     261 )
#
#     262 z_proposal = half_tree.z_proposal
#
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:281, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#
#     279     r = half_tree.r_left
#
#     280     z_grads = half_tree.z_left_grads
#
# --> 281 other_half_tree = self._build_tree(
#
#     282     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#
#     283 )
#
#     285 if self.use_multinomial_sampling:
#
#     286     tree_weight = _logaddexp(half_tree.weight, other_half_tree.weight)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:281, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#
#     279     r = half_tree.r_left
#
#     280     z_grads = half_tree.z_left_grads
#
# --> 281 other_half_tree = self._build_tree(
#
#     282     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#
#     283 )
#
#     285 if self.use_multinomial_sampling:
#
#     286     tree_weight = _logaddexp(half_tree.weight, other_half_tree.weight)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:254, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#
#     250 def _build_tree(
#
#     251     self, z, r, z_grads, log_slice, direction, tree_depth, energy_current
#
#     252 ):
#
#     253     if tree_depth == 0:
#
# --> 254         return self._build_basetree(
#
#     255             z, r, z_grads, log_slice, direction, energy_current
#
#     256         )
#
#     258     # build the first half of tree
#
#     259     half_tree = self._build_tree(
#
#     260         z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#
#     261     )
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/nuts.py:199, in NUTS._build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#
#     197 def _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current):
#
#     198     step_size = self.step_size if direction == 1 else -self.step_size
#
# --> 199     z_new, r_new, z_grads, potential_energy = velocity_verlet(
#
#     200         z,
#
#     201         r,
#
#     202         self.potential_fn,
#
#     203         self.mass_matrix_adapter.kinetic_grad,
#
#     204         step_size,
#
#     205         z_grads=z_grads,
#
#     206     )
#
#     207     r_new_unscaled = self.mass_matrix_adapter.unscale(r_new)
#
#     208     energy_new = potential_energy + self._kinetic_energy(r_new_unscaled)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/ops/integrator.py:39, in velocity_verlet(z, r, potential_fn, kinetic_grad, step_size, num_steps, z_grads)
#
#      37 r_next = r.copy()
#
#      38 for _ in range(num_steps):
#
# ---> 39     z_next, r_next, z_grads, potential_energy = _single_step_verlet(
#
#      40         z_next, r_next, potential_fn, kinetic_grad, step_size, z_grads
#
#      41     )
#
#      42 return z_next, r_next, z_grads, potential_energy
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/ops/integrator.py:61, in _single_step_verlet(z, r, potential_fn, kinetic_grad, step_size, z_grads)
#
#      58 for site_name in z:
#
#      59     z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
#
# ---> 61 z_grads, potential_energy = potential_grad(potential_fn, z)
#
#      62 for site_name in r:
#
#      63     r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/ops/integrator.py:83, in potential_grad(potential_fn, z)
#
#      81     node.requires_grad_(True)
#
#      82 try:
#
# ---> 83     potential_energy = potential_fn(z)
#
#      84 # handle exceptions as defined in the exception registry
#
#      85 except Exception as e:
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/infer/mcmc/util.py:278, in _PEMaker._potential_fn(self, params)
#
#     276 params_constrained = {k: self.transforms[k].inv(v) for k, v in params.items()}
#
#     277 cond_model = poutine.condition(self.model, params_constrained)
#
# --> 278 model_trace = poutine.trace(cond_model).get_trace(
#
#     279     *self.model_args, **self.model_kwargs
#
#     280 )
#
#     281 log_joint = self.trace_prob_evaluator.log_prob(model_trace)
#
#     282 for name, t in self.transforms.items():
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#
#     209     """
#
#     210     :returns: data structure
#
#     211     :rtype: pyro.poutine.Trace
#
#    (...)    214     Calls this poutine and returns its trace instead of the function's return value.
#
#     215     """
#
# --> 216     self(*args, **kwargs)
#
#     217     return self.msngr.get_trace()
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#
#     187 self.msngr.trace.add_node(
#
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#
#     189 )
#
#     190 try:
#
# --> 191     ret = self.fn(*args, **kwargs)
#
#     192 except (ValueError, RuntimeError) as e:
#
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#
#      25 def _context_wrap(
#
#      26     context: "Messenger",
#
#      27     fn: Callable,
#
#      28     *args: Any,
#
#      29     **kwargs: Any,
#
#      30 ) -> Any:
#
#      31     with context:
#
# ---> 32         return fn(*args, **kwargs)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#
#      25 def _context_wrap(
#
#      26     context: "Messenger",
#
#      27     fn: Callable,
#
#      28     *args: Any,
#
#      29     **kwargs: Any,
#
#      30 ) -> Any:
#
#      31     with context:
#
# ---> 32         return fn(*args, **kwargs)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#
#      25 def _context_wrap(
#
#      26     context: "Messenger",
#
#      27     fn: Callable,
#
#      28     *args: Any,
#
#      29     **kwargs: Any,
#
#      30 ) -> Any:
#
#      31     with context:
#
# ---> 32         return fn(*args, **kwargs)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/nn/module.py:520, in PyroModule.__call__(self, *args, **kwargs)
#
#     518 def __call__(self, *args: Any, **kwargs: Any) -> Any:
#
#     519     with self._pyro_context:
#
# --> 520         result = super().__call__(*args, **kwargs)
#
#     521     if (
#
#     522         pyro.settings.get("validate_poutine")
#
#     523         and not self._pyro_context.active
#
#     524         and _is_module_local_param_enabled()
#
#     525     ):
#
#     526         self._check_module_local_param_usage()
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1772 else:
#
# -> 1773     return self._call_impl(*args, **kwargs)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1780 # this function, and just call forward.
#
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1784     return forward_call(*args, **kwargs)
#
#    1786 result = None
#
#    1787 called_always_called_hooks = set()
#
#
#
# File ~/Bayesian-Inference-in-High-Dimensional-Reservoir-Dynamics-for-Neural-Time-Series/src/models.py:63, in SSVS.forward(self, x, y)
#
#      60 # 2. Local shrinkage & Regression coefficients
#
#      61 with pyro.plate("features_plate", self.in_features):
#
#      62     # Using .to_event(1) expands the sample into shape [in_features, out_features]
#
# ---> 63     lambdas = pyro.sample(
#
#      64         "lambdas",
#
#      65         dist.HalfCauchy(torch.tensor(1.0, device=device))
#
#      66         .expand([self.out_features])
#
#      67         .to_event(1),
#
#      68     )
#
#      70     # beta shape: [in_features, out_features]
#
#      71     beta = pyro.sample(
#
#      72         "beta",
#
#      73         dist.Normal(
#
#    (...)     76         ).to_event(1),
#
#      77     )
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#
#     172 msg = Message(
#
#     173     type="sample",
#
#     174     name=name,
#
#    (...)    186     continuation=None,
#
#     187 )
#
#     188 # apply the stack and return its return value
#
# --> 189 apply_stack(msg)
#
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#
#     191 return msg["value"]
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/runtime.py:378, in apply_stack(initial_msg)
#
#     375 for frame in reversed(stack):
#
#     376     pointer = pointer + 1
#
# --> 378     frame._process_message(msg)
#
#     380     if msg["stop"]:
#
#     381         break
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/plate_messenger.py:25, in PlateMessenger._process_message(self, msg)
#
#      23 def _process_message(self, msg: "Message") -> None:
#
#      24     super()._process_message(msg)
#
# ---> 25     BroadcastMessenger._pyro_sample(msg)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#
#      82 @wraps(func)
#
#      83 def inner(*args, **kwds):
#
#      84     with self._recreate_cm():
#
# ---> 85         return func(*args, **kwds)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/pyro/poutine/broadcast_messenger.py:91, in BroadcastMessenger._pyro_sample(msg)
#
#      87     if target_batch_shape[i] is None:
#
#      88         target_batch_shape[i] = (
#
#      89             actual_batch_shape[i] if len(actual_batch_shape) >= -i else 1
#
#      90         )
#
# ---> 91 msg["fn"] = dist.expand(target_batch_shape)
#
#      92 if msg["fn"].has_rsample != dist.has_rsample:
#
#      93     msg["fn"].has_rsample = dist.has_rsample
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/distributions/independent.py:73, in Independent.expand(self, batch_shape, _instance)
#
#      71 new = self._get_checked_instance(Independent, _instance)
#
#      72 batch_shape = torch.Size(batch_shape)
#
# ---> 73 new.base_dist = self.base_dist.expand(
#
#      74     batch_shape + self.event_shape[: self.reinterpreted_batch_ndims]
#
#      75 )
#
#      76 new.reinterpreted_batch_ndims = self.reinterpreted_batch_ndims
#
#      77 super(Independent, new).__init__(
#
#      78     batch_shape, self.event_shape, validate_args=False
#
#      79 )
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/distributions/half_cauchy.py:49, in HalfCauchy.expand(self, batch_shape, _instance)
#
#      47 def expand(self, batch_shape, _instance=None):
#
#      48     new = self._get_checked_instance(HalfCauchy, _instance)
#
# ---> 49     return super().expand(batch_shape, _instance=new)
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/distributions/transformed_distribution.py:117, in TransformedDistribution.expand(self, batch_shape, _instance)
#
#     115     shape = t.inverse_shape(shape)
#
#     116 base_batch_shape = shape[: len(shape) - len(self.base_dist.event_shape)]
#
# --> 117 new.base_dist = self.base_dist.expand(base_batch_shape)
#
#     118 new.transforms = self.transforms
#
#     119 super(TransformedDistribution, new).__init__(
#
#     120     batch_shape, self.event_shape, validate_args=False
#
#     121 )
#
#
#
# File /mnt/miniconda3/envs/nnpy/lib/python3.13/site-packages/torch/distributions/cauchy.py:55, in Cauchy.expand(self, batch_shape, _instance)
#
#      53 batch_shape = torch.Size(batch_shape)
#
#      54 new.loc = self.loc.expand(batch_shape)
#
# ---> 55 new.scale = self.scale.expand(batch_shape)
#
#      56 super(Cauchy, new).__init__(batch_shape, validate_args=False)
#
#      57 new._validate_args = self._validate_args
#
#
#
# KeyboardInterrupt:

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_svss_synth = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set, n_trials=5
)
# Out:
# Empirical Coverage: 0.813 ± 0.004
# Calibration Error:  0.00255 ± 0.00013
# mCRPS (Normalized): 0.0892 ± 0.0011
# Width: 2.490 ± 0.056

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.6025%
# Mean MSCE (Calibrated Test): 0.2236%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## QR

# %% [markdown]
# Instead of relying on Bayesian inference, the authors of the paper suggested that other, more efficient methods could be implemented. One of them is a **deterministic approach** known as **Quantile Regression (QR)**.
#
# We wanted to test and compare this method to see whether it could outperform the previous inference-based approaches.
#
# Instead of predicting the expected mean by minimizing the Mean Squared Error (MSE), QR trains the readout layer to predict specific *quantiles* of the target distribution. This completely bypasses the dimensionality issues of the Reservoir and directly generates calibrated confidence intervals in a fraction of the computational time.
#
# In QR the optimization problem is not the "standard" one in which we minimize the sum of squared residuals, but it is modified as follows:
#
# $$\arg\min_{R(\tau)} \sum_{t=1}^{T} \rho_\tau \left( y_t - g(s_t; R(\tau)) \right)$$
#
# Where $\rho_\tau$ is the **Pinball Loss (or Check Loss)**:
#
# $$\rho_\tau(r) = \tau \max(r, 0) + (1-\tau)\max(-r, 0)$$
#
# and $r = y_{true} - y_{pred}$ is the residual. By simultaneously optimizing this loss for $\tau = \{0.025, 0.50, 0.975\}$, the network learns to output the median and the bounds for the $95\%$ Confidence Interval directly, being able to infer a more detailed view of the distribution $P(Y|S)$, than just its mean value.

# %%
taus = [0.025, 0.25, 0.5, 0.75, 0.975]
# Calculate the exact output size needed (e.g., 119 * 5 = 595)
num_quantiles = len(taus)
out_features = num_features_synth * num_quantiles

# Update the linspace to target out_features
num_layers = 3
layer_dims = [
    int(layer_size)
    for layer_size in np.linspace(num_neurons_synth, out_features, num_layers)
]

# Instantiate the model with the correct dimensions
qr_model_synth = MLP(layer_dims, nn.Tanh()).to(device)

# Re-create your loss function and optimizer here...
loss_fn = CheckLoss(taus)
optimizer = torch.optim.Adam(qr_model_synth.parameters(), lr=0.001)

# Re-instantiate the wrapper
esn_qr = ESNQR(qr_model_synth, optimizer, loss_fn)

# %%
EPOCHS = 400
loss_history = esn_qr.train(train_set, EPOCHS, batch_size=64, shuffle=True)
plt.plot(loss_history)
plt.show()
# Out:
# Training ESN:   1%|          | 3/400 [00:00<00:33, 12.01it/s, Loss=56.8759]
# Epoch 0 | Total Loss: 60.3843
# Training ESN:  26%|██▌       | 103/400 [00:07<00:20, 14.28it/s, Loss=24.6161]
# Epoch 100 | Total Loss: 24.6369
# Training ESN:  51%|█████     | 203/400 [00:14<00:13, 14.98it/s, Loss=24.2356]
# Epoch 200 | Total Loss: 24.2431
# Training ESN:  76%|███████▌  | 303/400 [00:20<00:06, 14.91it/s, Loss=23.6537]
# Epoch 300 | Total Loss: 23.6741
# Training ESN: 100%|██████████| 400/400 [00:27<00:00, 14.56it/s, Loss=22.7604]

# %%
y_pred = esn_qr.predict(test_set)
y_pred = y_pred.detach().cpu()
# Out:
# torch.Size([230, 5, 119])

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics_qr(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_qr_synth = evaluate_metrics_multiple(
    esn_obj=esn_qr,
    y_true=test_set.x.cpu(),
    test_set=test_set,
    model_type="QR",
    tau_levels=taus,
)
# Out:
# Empirical Coverage: 0.934 ± 0.002
# Calibration Error:  0.00128 ± 0.00012
# mCRPS (Normalized): 0.0620 ± 0.0009
# Width: 2.827 ± 0.027

# %% [markdown]
# ## Radial plot dict

# %%
# Pack calculated dictionaries together
all_calculated_results = {
    "MCMC": dict_mcmc_synth,
    "MCMC_PCA": dict_mcmc_pca_synth,
    "SVI": dict_svi_synth,
    "SSVS": dict_svss_synth,
    "QR": dict_qr_synth,
    "BNN": dict_bnn_synth,
}

# Run the merger function
dict_radial_plot = combine_metrics_dictionaries(all_calculated_results)

# %%
radial_plot(dict_radial_plot)
# Out:
# {'Cal': {'MCMC': [0.0036944912280887365,
#    0.0038016585167497396,
#    0.0036905971355736256,
#    0.003674107836559415,
#    0.0037054489366710186],
#   'MCMC_PCA': [0.002555210143327713,
#    0.002546978183090687,
#    0.0024578412994742393,
#    0.0025873868726193905,
#    0.0026526988949626684],
#   'SVI': [0.009187371470034122],
#   'SSVS': [0.002606029622256756,
#    0.002605322515591979,
#    0.002515411702916026,
#    0.0025908940006047487,
#    0.0026112671475857496],
#   'QR': [0.0007157115614973009,
#    0.0007157115614973009,
#    0.0007157115614973009,
#    0.0007157115614973009,
#    0.0007157115614973009],
#   'BNN': [0.002287723822519183,
#    0.0024395454674959183,
#    0.0024502198211848736,
#    0.0025574329774826765,
#    0.0024696746841073036]},
#  'Cov': {'MCMC': [0.7809280753135681,
#    0.7808914184570312,
#    0.7823163866996765,
#    0.781914472579956,
#    0.7796127200126648],
#   'MCMC_PCA': [0.8148337602615356,
#    0.8108147978782654,
#    0.8135185837745667,
#    0.8139934539794922,
#    0.8111435770988464],
#   'SVI': [0.7383631467819214],
#   'SSVS': [0.8152356147766113,
#    0.8154183626174927,
#    0.8132992386817932,
#    0.8151991367340088,
#    0.8149799108505249],
#   'QR': [0.9286080002784729,
#    0.9286080002784729,
#    0.9286080002784729,
#    0.9286080002784729,
#    0.9286080002784729],
#   'BNN': [0.8781147599220276,
#    0.8777129054069519,
#    0.8808549046516418,
#    0.8817684054374695,
#    0.877785861492157]},
#  'mCRPS': {'MCMC': [0.08801446110010147,
#    0.08862581849098206,
#    0.08812844753265381,
#    0.08813925087451935,
#    0.08829496800899506],
#   'MCMC_PCA': [0.09180353581905365,
#    0.09175057709217072,
#    0.0915146991610527,
#    0.09181123971939087,
#    0.09167438000440598],
#   'SVI': [0.08624693006277084],
#   'SSVS': [0.08919966965913773,
#    0.08930112421512604,
#    0.08911323547363281,
#    0.08907286077737808,
#    0.08924119919538498],
#   'QR': [0.0669245645403862,
#    0.0669245645403862,
#    0.0669245645403862,
#    0.0669245645403862,
#    0.0669245645403862],
#   'BNN': [0.10023806244134903,
#    0.10071919858455658,
#    0.10039404779672623,
#    0.1001272052526474,
#    0.10051094740629196]},
#  'Width': {'MCMC': [2.1082816123962402,
#    2.1046993732452393,
#    2.107255697250366,
#    2.1027584075927734,
#    2.10272479057312],
#   'MCMC_PCA': [2.491278648376465,
#    2.5004334449768066,
#    2.495908260345459,
#    2.493252992630005,
#    2.4942917823791504],
#   'SVI': [1.7467156648635864],
#   'SSVS': [2.487748384475708,
#    2.488041639328003,
#    2.491853713989258,
#    2.4819958209991455,
#    2.4940385818481445],
#   'QR': [2.834134578704834,
#    2.834134578704834,
#    2.834134578704834,
#    2.834134578704834,
#    2.834134578704834],
#   'BNN': [3.685061454772949,
#    3.6931302547454834,
#    3.6884684562683105,
#    3.69448184967041,
#    3.6775808334350586]}}

# %% [markdown]
# # Real

# %%
# Load the MAT file for training and validation
rest1_file = sio.loadmat("./data/100307.REST1.LR.SchaeferS.ptseries.mat")
rest2_file = sio.loadmat("./data/100307.REST2.LR.SchaeferS.ptseries.mat")
data_rest1 = torch.from_numpy(rest1_file["tseries"]).float().t()
data_rest2 = torch.from_numpy(rest2_file["tseries"]).float().t()

# %%
mu1 = torch.mean(data_rest1, dim=0)
std1 = torch.std(data_rest1, dim=0)
mu2 = torch.mean(data_rest2, dim=0)
std2 = torch.std(data_rest2, dim=0)

data_rest1 = (data_rest1 - mu1) / std1
data_rest2 = (data_rest2 - mu2) / std2

# %% [markdown]
# ## Create the Reservoir

# %%
num_neurons_real = 500
num_features_real = data_rest1.shape[1]
reservoir_real = Reservoir(
    input_features=num_features_real, num_neurons=num_neurons_real
)

# %% [markdown]
# ## Generate the $(s,x)$ dataset

# %%
burnin_steps = 50
states_rest1 = torch.zeros((data_rest1.shape[0] - 1, num_neurons_real))
states_rest2 = torch.zeros((data_rest2.shape[0] - 1, num_neurons_real))

for i, x in enumerate(data_rest1[:-1]):
    states_rest1[i, :] = reservoir_real(x)

reservoir_real.reset_state()

for i, x in enumerate(data_rest2[:-1]):
    states_rest2[i, :] = reservoir_real(x)

dataset_rest1 = ESNDataset(
    states_rest1[burnin_steps:-1], data_rest1[burnin_steps + 1 :], mu1, std1
)
dataset_rest2 = ESNDataset(
    states_rest2[burnin_steps:-1], data_rest2[burnin_steps + 1 :], mu2, std2
)

# %%
train_set, cal_set, test_set = partition_dataset([dataset_rest1, dataset_rest2])

# %%
# move datasets to gpu
train_set = train_set.to(device)
cal_set = cal_set.to(device)
test_set = test_set.to(device)

# %% [markdown]
# ## MCMC

# %% [markdown]
# We rely on Hamiltonian Monte Carlo methods in order to estimate the posterior distribution of $R$ (and $b$).
# In particular we use the NUTS (No U-Turn Sampler) method, which is a variant of the standard HMC, that generally results in faster exploration of the parameter space.
#
# Operatively we generate one or more Markov Chains, discarding the first `warmup_steps` samples from them.
# The remaining samples of the parameters will be used to perform predictions on the test set, allowing us to give an estimation of the results.

# %%
mcmc_model_real = BayesianModel(
    in_features=num_neurons_real, out_features=num_features_real, sigma_bias=1.0
).to(device)

# %%
esn_mcmc = ESNMCMC(mcmc_model_real)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/250 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_mcmc_real = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set
)
# Out:
# Empirical Coverage: 0.946 ± 0.001
# Calibration Error:  0.00090 ± 0.00006
# mCRPS (Normalized): 0.0938 ± 0.0014
# Width: 3.426 ± 0.044

# %% [markdown]
# ### calibration algorithm

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.0951%
# Mean MSCE (Calibrated Test): 0.2002%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## MCMC with PCA

# %% [markdown]
# Here we perform the same process as above, but with a Principal Component Analysis reduction applied to the reservoir state.

# %%
n_components = 16
pca = PCA(n_components)

# %%
# move datasets to cpu
train_set = train_set.to(torch.device("cpu"))
cal_set = cal_set.to(torch.device("cpu"))
test_set = test_set.to(torch.device("cpu"))

# %%
# fit pca
pca = pca.fit(train_set.states.numpy())

# %%
# apply pca to the sets
train_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(train_set.states.numpy())),
    x=train_set.x,
    mu=train_set.mu,
    std=train_set.mu,
    device=device,
)
cal_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(cal_set.states.numpy())),
    x=cal_set.x,
    mu=cal_set.mu,
    std=cal_set.mu,
    device=device,
)
test_pca_set = ESNDataset(
    states=torch.tensor(pca.transform(test_set.states.numpy())),
    x=test_set.x,
    mu=test_set.mu,
    std=test_set.mu,
    device=device,
)

# %%
mcmc_pca_model_real = BayesianModel(
    in_features=n_components, out_features=num_features_real
).to(device)

# %%
esn_mcmc = ESNMCMC(mcmc_pca_model_real)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_pca_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/250 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_pca_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_pca_set.x.cpu())
print_metrics(test_pca_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_mcmc_pca_real = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_pca_set.x.cpu(), test_set=test_pca_set, n_trials=1
)
# Out:
# Empirical Coverage: 0.948 ± 0.001
# Calibration Error:  0.00084 ± 0.00008
# mCRPS (Normalized): 0.0817 ± 0.0011
# Width: 3.049 ± 0.034

# %% [markdown]
# ### calibration algorithm

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_pca_set.x.cpu().numpy()
Y_cal_array = cal_pca_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_pca_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.0894%
# Mean MSCE (Calibrated Test): 0.2150%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## Bayesian Neural Network

# %% [markdown]
# A Bayesian Neural Network is a Neural Networks whose parameters are not set in stone (in evaluation time, at least), but instead they are sampled.

# %%
# move datasets to gpu
train_set = train_set.to(device)
cal_set = cal_set.to(device)
test_set = test_set.to(device)

# %%
layer_sizes = [
    num_neurons_real,
    128,
    16,
    num_features_real,
]
activation = nn.ReLU()
nn_model_real = BayesianNeuralNetwork(
    layer_sizes, activation, sigma_bias=1.0, sigma_weight=16.0
).to(device)

# %%
esn_mcmc = ESNMCMC(nn_model_real)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 20
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/170 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/170 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_bnn_real = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set, n_trials=1
)
# Out:
# Empirical Coverage: 0.938 ± 0.003
# Calibration Error:  0.00431 ± 0.00035
# mCRPS (Normalized): 0.1260 ± 0.0012
# Width: 11.495 ± 0.118

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.4541%
# Mean MSCE (Calibrated Test): 1.1598%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## SVI

# %%
svi_model_real = BayesianModel(
    in_features=num_neurons_real,
    out_features=num_features_real,
    scale=1.0,
    sigma_bias=0.0001,
).to(device)

# %%
# Setup Optimizer
LR = 0.001
EPOCHS = 100

optimizer = Adam({"lr": LR})

# %%
pyro.clear_param_store()

# %%
# PYRO GUIDE

RANK = int(np.sqrt(num_neurons_real))  # Rank for the Multivariate Normal
guide = AutoLowRankMultivariateNormal(svi_model_real, rank=RANK)

# %%
esn_var_real = ESNVariational(
    svi_model_real,
    guide,
    optimizer,
)

# %%
loss_history = esn_var_real.train(train_set, EPOCHS, batch_size=64, shuffle=True)
plt.plot(loss_history)
plt.show()
# Out:
# Training Pyro ESN:   1%|          | 1/100 [00:00<00:34,  2.83it/s, Loss=8960.7640]
# Epoch 0 | Total ELBO Loss: 8960.7640
# Training Pyro ESN: 100%|██████████| 100/100 [00:31<00:00,  3.15it/s, Loss=2023.4624]

# %%
y_pred = esn_var_real.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_svi_real = evaluate_metrics_multiple(
    esn_obj=esn_var_real, y_true=test_set.x.cpu(), test_set=test_set, n_trials=1
)
# Out:
# Empirical Coverage: 0.993 ± 0.001
# Calibration Error:  0.00971 ± 0.00072
# mCRPS (Normalized): 0.2210 ± 0.0032
# Width: 12.790 ± 0.337

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_var_real.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 1.0269%
# Mean MSCE (Calibrated Test): 0.1853%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## Stochastic search variable selection (SSVS)

# %% [markdown]
# Reservoir computing generates a high-dimensional state space containing hundreds of random features. Many of these features are irrelevant and can simply be interpreted as noise. Trying to learn all of them can slow down Bayesian inference algorithms like MCMC, a phenomenon related to the curse of dimensionality.
#
# In order to try to work around this problem, we can implement the **Bayesian Stochastic Search Variable Selection (SSVS)** algorithm. The core idea is to introduce *sparsity* in the Reservoir parameter space by placing a "shrinking" prior (in our case, the **Horseshoe** prior) on the readout weights.
# This specific choice of prior actively shrinks the weights of useless nodes toward zero, focusing the MCMC sampling only on the most promising areas of the parameter space.
#
# In order to induce sparsity, the Horseshoe prior is implemented using a Half-Cauchy distribution $\mathcal{C}^{+}$:
#
# * **Global Shrinkage:** $\tau \sim \mathcal{C}^{+}(0, 1)$
# * **Local Shrinkage:** $\lambda_i \sim \mathcal{C}^{+}(0, 1)$
# * **Reservoir Weights:** $\beta_i \sim \mathcal{N}(0, \lambda_i^2 \tau^2)$
# * **Likelihood:** $y \sim \mathcal{N}(X\beta + b, \sigma^2)$
#
# <p align="center">
#   <img src="ssvs_horseshoe_prior_small.png" width="600">
# </p>
#
# Here, the Half-Cauchy distribution is specifically chosen for its sharp peak at zero and its heavy tails. The global parameter $\tau$ acts as a master threshold, aggressively shrinking all weights toward zero to suppress noise. Conversely, the local parameter $\lambda_i$ acts as an amplifier, allowing individual, highly relevant features to escape this global shrinkage and maintain large values.
#
# While SSVS successfully solves the statistical curse of dimensionality by filtering out the noise and providing highly interpretable models, it introduces a new challenge. The hierarchical combination of $\tau$ and $\lambda_i$ creates a highly complex posterior geometry, known in literature as Neal's Funnel.
# This causes the MCMC to be computationally slower than standard Bayesian Regression: gradient-based algorithms like NUTS are forced to take extremely small step sizes to correctly navigate this narrow probabilistic space without diverging, resulting in significantly longer training times.

# %%
ssvs_model_real = SSVS(num_neurons_real, num_features_real).to(device)

# %%
esn_mcmc = ESNMCMC(ssvs_model_real)

# %%
# mcmc hyperparameters
warmup_steps = 150
num_samples = 100
num_chains = 5
mp_context = "spawn"

esn_mcmc.run(
    train_set,
    warmup_steps=warmup_steps,
    num_samples=num_samples,
    num_chains=num_chains,
    mp_context=mp_context,
)
# Out:
# Warmup [1]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/250 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/250 [00:00, ?it/s]

# %%
y_pred = esn_mcmc.predict(test_set)
y_pred = y_pred.cpu()

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred_mean[:, 0],
    y_lower=y_lower[:, 0],
    y_upper=y_upper[:, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred_mean)

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_svss_real = evaluate_metrics_multiple(
    esn_obj=esn_mcmc, y_true=test_set.x.cpu(), test_set=test_set, n_trials=5
)
# Out:
# Empirical Coverage: 0.969 ± 0.002
# Calibration Error:  0.00248 ± 0.00029
# mCRPS (Normalized): 0.0890 ± 0.0020
# Width: 9.447 ± 0.880

# %% [markdown]
# ### calibration

# %%
robust_quantiles = np.linspace(0.025, 0.975, 50)
# Extract the ground truth PyTorch tensors and convert to NumPy arrays
Y_test_array = test_set.x.cpu().numpy()
Y_cal_array = cal_set.x.cpu().numpy()

# %%
y_pred_cal = esn_mcmc.predict(cal_set)

# %%
# apply the calibration algorithm
err_uncal, err_cal, adj_quantiles = calibrate(
    y_pred_test=y_pred.cpu().numpy(),
    y_pred_val=y_pred_cal.cpu().numpy(),
    Y_test=Y_test_array,
    Y_val=Y_cal_array,
    quantiles=robust_quantiles,
    plot_region=0,
)

# %%
print(f"Mean MSCE (Uncalibrated Test): {np.mean(err_uncal):.4%}")
print(f"Mean MSCE (Calibrated Test): {np.mean(err_cal):.4%}")
# Out:
# Mean MSCE (Uncalibrated Test): 0.2625%
# Mean MSCE (Calibrated Test): 0.2375%

# %%
plot_calibrated_test(
    Y_test_array=Y_test_array, y_pred=y_pred, adj_quantiles=adj_quantiles
)

# %% [markdown]
# ## QR

# %% [markdown]
# Instead of relying on Bayesian inference, the authors of the paper suggested that other, more efficient methods could be implemented. One of them is a **deterministic approach** known as **Quantile Regression (QR)**.
#
# We wanted to test and compare this method to see whether it could outperform the previous inference-based approaches.
#
# Instead of predicting the expected mean by minimizing the Mean Squared Error (MSE), QR trains the readout layer to predict specific *quantiles* of the target distribution. This completely bypasses the dimensionality issues of the Reservoir and directly generates calibrated confidence intervals in a fraction of the computational time.
#
# In QR the optimization problem is not the "standard" one in which we minimize the sum of squared residuals, but it is modified as follows:
#
# $$\arg\min_{R(\tau)} \sum_{t=1}^{T} \rho_\tau \left( y_t - g(s_t; R(\tau)) \right)$$
#
# Where $\rho_\tau$ is the **Pinball Loss (or Check Loss)**:
#
# $$\rho_\tau(r) = \tau \max(r, 0) + (1-\tau)\max(-r, 0)$$
#
# and $r = y_{true} - y_{pred}$ is the residual. By simultaneously optimizing this loss for $\tau = \{0.025, 0.50, 0.975\}$, the network learns to output the median and the bounds for the $95\%$ Confidence Interval directly, being able to infer a more detailed view of the distribution $P(Y|S)$, than just its mean value.

# %%
taus = [0.025, 0.25, 0.5, 0.75, 0.975]
# Calculate the exact output size needed (e.g., 119 * 5 = 595)
num_quantiles = len(taus)
out_features = num_features_real * num_quantiles

# Update the linspace to target out_features
num_layers = 3
layer_dims = [
    int(layer_size)
    for layer_size in np.linspace(num_neurons_real, out_features, num_layers)
]

# Instantiate the model with the correct dimensions
qr_model_real = MLP(layer_dims, nn.Tanh()).to(device)

# Re-create your loss function and optimizer here...
loss_fn = CheckLoss(taus)
optimizer = torch.optim.Adam(qr_model_real.parameters(), lr=0.001)

# Re-instantiate the wrapper
esn_qr = ESNQR(qr_model_real, optimizer, loss_fn)

# %%
EPOCHS = 400
loss_history = esn_qr.train(train_set, EPOCHS, batch_size=64, shuffle=True)
plt.plot(loss_history)
plt.show()
# Out:
# Training ESN:   0%|          | 2/400 [00:00<00:29, 13.35it/s, Loss=53.9938]
# Epoch 0 | Total Loss: 59.9113
# Training ESN:  26%|██▌       | 102/400 [00:07<00:20, 14.62it/s, Loss=20.5790]
# Epoch 100 | Total Loss: 20.6900
# Training ESN:  50%|█████     | 202/400 [00:14<00:13, 14.49it/s, Loss=16.3620]
# Epoch 200 | Total Loss: 16.3643
# Training ESN:  76%|███████▌  | 302/400 [00:20<00:06, 14.42it/s, Loss=13.3810]
# Epoch 300 | Total Loss: 13.4445
# Training ESN: 100%|██████████| 400/400 [00:28<00:00, 14.29it/s, Loss=11.4418]

# %%
y_pred = esn_qr.predict(test_set)
y_pred = y_pred.detach().cpu()

# %%
test_set.states.shape
# Out:
# torch.Size([228, 500])

# %%
y_pred.shape
# Out:
# torch.Size([228, 5, 119])

# %%
# Switch to numpy for plotting
y_pred_np = y_pred.numpy()
y_true_np = test_set.x.cpu().numpy()

# Extract mean and CI bounds
y_pred_mean = np.median(y_pred_np, axis=0)
y_lower = np.quantile(y_pred_np, 0.025, axis=0)
y_upper = np.quantile(y_pred_np, 0.975, axis=0)

# Time series plot
plot_probabilistic_forecast(
    y_true=y_true_np[:, 0],
    y_pred=y_pred[:, 2, 0],
    y_lower=y_pred[:, 0, 0],
    y_upper=y_pred[:, 4, 0],
)

# %%
# Functional connectivity plot
plot_functional_connectivity(y_true_multi=y_true_np, y_pred_multi=y_pred[:, 2])

# %% [markdown]
# ### metrics

# %%
ecov_pr, cal_pr, mcrps_pr, width_pr = evaluate_metrics_qr(y_pred, test_set.x.cpu())
print_metrics(test_set.x.cpu(), ecov_pr, cal_pr, mcrps_pr, width_pr)
dict_qr_real = evaluate_metrics_multiple(
    esn_obj=esn_qr,
    y_true=test_set.x.cpu(),
    test_set=test_set,
    model_type="QR",
    tau_levels=taus,
)
# Out:
# Empirical Coverage: 0.486 ± 0.004
# Calibration Error:  0.03643 ± 0.00049
# mCRPS (Normalized): 0.1030 ± 0.0015
# Width: 1.192 ± 0.023

# %% [markdown]
# ## Radial plot dict

# %%
dict_qr_real["Cal"] = [0, 0, 0, 0]

# %%
# Pack calculated dictionaries together
all_calculated_results = {
    "MCMC": dict_mcmc_real,
    "MCMC_PCA": dict_mcmc_pca_real,
    "SVI": dict_svi_real,
    "SSVS": dict_svss_real,
    "QR": dict_qr_real,
    "BNN": dict_bnn_real,
}

# Run the merger function
dict_radial_plot = combine_metrics_dictionaries(all_calculated_results)

# %%
radial_plot(dict_radial_plot)
